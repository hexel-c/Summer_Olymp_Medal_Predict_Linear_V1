# %% [markdown]
# ## **Loading The Data Set**

# %%
import pandas as pd

df = pd.read_csv("DataSet/teams.csv")

teams = df[["team", "country", "year", "athletes", "age", "height", "weight", "prev_medals", "medals"]]

teams
# Out:
#      team      country  year  athletes   age  height  weight  prev_medals  \
# 0     AFG  Afghanistan  1964         8  22.0   161.0    64.2          0.0
# 1     AFG  Afghanistan  1968         5  23.2   170.2    70.0          0.0
# 2     AFG  Afghanistan  1972         8  29.0   168.3    63.8          0.0
# 3     AFG  Afghanistan  1980        11  23.6   168.4    63.2          0.0
# 4     AFG  Afghanistan  2004         5  18.6   170.8    64.8          0.0
# ...   ...          ...   ...       ...   ...     ...     ...          ...
# 2139  ZIM     Zimbabwe  2000        26  25.0   179.0    71.1          0.0
# 2140  ZIM     Zimbabwe  2004        14  25.1   177.8    70.5          0.0
# 2141  ZIM     Zimbabwe  2008        16  26.1   171.9    63.7          3.0
# 2142  ZIM     Zimbabwe  2012         9  27.3   174.4    65.2          4.0
# 2143  ZIM     Zimbabwe  2016        31  27.5   167.8    62.2          0.0
#
#       medals
# 0          0
# 1          0
# 2          0
# 3          0
# ...

# %% [markdown]
# ## **Checking for Correlation**

# %%
teams.select_dtypes(include=['number']).corr()["medals"]
# Out:
# year          -0.021603
# athletes       0.840817
# age            0.025096
# height         0.141055
# weight         0.090577
# prev_medals    0.920048
# medals         1.000000
# Name: medals, dtype: float64

# %% [markdown]
# ## **Visualize Correlation**

# %%
import seaborn as sns

# %% [markdown]
# Correlation between athletes and medals

# %%
sns.lmplot(x="athletes", y="medals", data=teams, fit_reg=True, ci=None)

# %% [markdown]
# Correlation between age and medals

# %%
sns.lmplot(x="age", y="medals", data=teams, fit_reg=True, ci=None)

# %% [markdown]
# Correlation between height and medals

# %%
sns.lmplot(x="height", y="medals", data=teams, fit_reg=True, ci=None)

# %% [markdown]
# Correlation between weight and medals

# %%
sns.lmplot(x="weight", y="medals", data=teams, fit_reg=True, ci=None)

# %%
teams.plot.hist(y="medals")
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# ## **Cleaning Data**

# %% [markdown]
# Check for missing data

# %%
teams[teams.isnull().any(axis=1)]
# Out:
#      team                           country  year  athletes   age  height  \
# 19    ALB                           Albania  1992         9  25.3   163.0
# 26    ALG                           Algeria  1964         7  26.0   175.0
# 39    AND                           Andorra  1976         3  28.3   174.7
# 50    ANG                            Angola  1980        17  17.4   171.7
# 59    ANT               Antigua and Barbuda  1976        17  23.2   178.6
# ...   ...                               ...   ...       ...   ...     ...
# 2092  VIN  Saint Vincent and the Grenadines  1988         6  20.5   157.0
# 2103  YAR                       North Yemen  1984         3  27.7   163.3
# 2105  YEM                             Yemen  1992         8  19.6   169.0
# 2112  YMD                       South Yemen  1988         5  23.6   175.0
# 2120  ZAM                            Zambia  1964        15  21.7   175.7
#
#       weight  prev_medals  medals
# 19      75.2          NaN       0
# ...

# %% [markdown]
# Drop Missing Data

# %%
teams=teams.dropna()

teams
# Out:
#      team      country  year  athletes   age  height  weight  prev_medals  \
# 0     AFG  Afghanistan  1964         8  22.0   161.0    64.2          0.0
# 1     AFG  Afghanistan  1968         5  23.2   170.2    70.0          0.0
# 2     AFG  Afghanistan  1972         8  29.0   168.3    63.8          0.0
# 3     AFG  Afghanistan  1980        11  23.6   168.4    63.2          0.0
# 4     AFG  Afghanistan  2004         5  18.6   170.8    64.8          0.0
# ...   ...          ...   ...       ...   ...     ...     ...          ...
# 2139  ZIM     Zimbabwe  2000        26  25.0   179.0    71.1          0.0
# 2140  ZIM     Zimbabwe  2004        14  25.1   177.8    70.5          0.0
# 2141  ZIM     Zimbabwe  2008        16  26.1   171.9    63.7          3.0
# 2142  ZIM     Zimbabwe  2012         9  27.3   174.4    65.2          4.0
# 2143  ZIM     Zimbabwe  2016        31  27.5   167.8    62.2          0.0
#
#       medals
# 0          0
# 1          0
# 2          0
# 3          0
# ...

# %% [markdown]
# ## **Making The Model**

# %% [markdown]
# Split Data

# %%
train = teams[teams["year"] < 2012].copy()

test = teams[teams["year"] >= 2012].copy()

# %% [markdown]
# Check rows and columns of training and test sets

# %%
train.shape
# Out:
# (1609, 9)

# %%
test.shape
# Out:
# (405, 9)

# %% [markdown]
# ## **Training The Model**

# %%
from sklearn.linear_model import LinearRegression

reg = LinearRegression() # This is the trained model

# %% [markdown]
# Creating Predictors

# %%
predictors = ["athletes", "age", "height", "weight", "prev_medals"]

# %% [markdown]
# Create Target

# %%
target = "medals"

# %% [markdown]
# ## **Fit the model**

# %%
reg.fit(train[predictors], train["medals"])
# Out:
# LinearRegression()

# %% [markdown]
# ## **Making Predictions**

# %%
predictions = reg.predict(test[predictors])

predictions
# Out:
# array([-1.02885496e+00, -1.07072549e+00, -1.44215653e+00, -1.83323021e+00,
#         2.07335457e+00,  3.95195516e+00, -2.24549632e+00, -1.87997477e+00,
#         2.32555445e-01, -4.31175393e-01, -1.78779083e+00, -1.44913187e+00,
#         4.64138349e+01,  2.84485977e+01,  4.69034694e+00,  2.87464060e+00,
#        -1.35772244e+00, -1.63479751e+00, -1.26353470e+00, -1.94730155e+00,
#         1.46384834e+02,  1.20365241e+02,  6.16175029e+00,  3.60681047e+00,
#         7.50462535e+00,  1.02061851e+01,  4.92091310e+00,  3.31388062e+00,
#        -9.42241338e-01, -1.05025159e+00, -1.93681651e+00, -1.53595987e+00,
#        -1.51526617e+00, -1.51284036e+00,  1.14226826e+01,  9.81875057e+00,
#        -2.03243748e+00, -1.97033255e+00, -2.00803277e+00, -1.62138993e+00,
#        -1.26621522e+00, -1.74111966e+00, -2.29090311e+00, -1.42312536e+00,
#        -1.57972440e+00, -2.50033119e+00,  3.26615268e+01,  2.50330503e+01,
# ...

# %% [markdown]
# **re-scale predictions to make it more readable and clearer**

# %% [markdown]
# Assign predictions to a column in our test dataframe

# %%
test["predictions"] = predictions

test
# Out:
#      team      country  year  athletes   age  height  weight  prev_medals  \
# 6     AFG  Afghanistan  2012         6  24.8   171.7    60.8          1.0
# 7     AFG  Afghanistan  2016         3  24.7   173.7    74.0          1.0
# 24    ALB      Albania  2012        10  25.7   176.8    80.2          0.0
# 25    ALB      Albania  2016         6  23.7   176.2    67.2          0.0
# 37    ALG      Algeria  2012        39  24.8   174.3    66.9          2.0
# ...   ...          ...   ...       ...   ...     ...     ...          ...
# 2111  YEM        Yemen  2016         3  19.3   169.7    65.7          0.0
# 2131  ZAM       Zambia  2012         7  22.6   176.2    74.2          0.0
# 2132  ZAM       Zambia  2016         7  24.1   175.2    67.5          0.0
# 2142  ZIM     Zimbabwe  2012         9  27.3   174.4    65.2          4.0
# 2143  ZIM     Zimbabwe  2016        31  27.5   167.8    62.2          0.0
#
#       medals  predictions
# 6          1    -1.028855
# ...

# %% [markdown]
# Replace prediction value <0 to 0 (remove neagtives)

# %%
test.loc[test["predictions"] < 0, "predictions"] = 0

# %% [markdown]
# Round up the data

# %%
test["predictions"] = test["predictions"].round()

# %%
test
# Out:
#      team      country  year  athletes   age  height  weight  prev_medals  \
# 6     AFG  Afghanistan  2012         6  24.8   171.7    60.8          1.0
# 7     AFG  Afghanistan  2016         3  24.7   173.7    74.0          1.0
# 24    ALB      Albania  2012        10  25.7   176.8    80.2          0.0
# 25    ALB      Albania  2016         6  23.7   176.2    67.2          0.0
# 37    ALG      Algeria  2012        39  24.8   174.3    66.9          2.0
# ...   ...          ...   ...       ...   ...     ...     ...          ...
# 2111  YEM        Yemen  2016         3  19.3   169.7    65.7          0.0
# 2131  ZAM       Zambia  2012         7  22.6   176.2    74.2          0.0
# 2132  ZAM       Zambia  2016         7  24.1   175.2    67.5          0.0
# 2142  ZIM     Zimbabwe  2012         9  27.3   174.4    65.2          4.0
# 2143  ZIM     Zimbabwe  2016        31  27.5   167.8    62.2          0.0
#
#       medals  predictions
# 6          1          0.0
# ...

# %% [markdown]
# **Check for mean absolute error**

# %%
from sklearn.metrics import mean_absolute_error

error = mean_absolute_error(test["medals"], test["predictions"])

# %%
error
# Out:
# 3.254320987654321

# %% [markdown]
# Check if our mean prediction error is a good or bad error

# %%
teams.describe()["medals"]
# Out:
# count    2014.000000
# mean       10.990070
# std        33.627528
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         5.000000
# max       442.000000
# Name: medals, dtype: float64

# %% [markdown]
# **Look team by team to see how our predictions look**

# %%
test[test["team"] == "USA"]
# Out:
#      team        country  year  athletes   age  height  weight  prev_medals  \
# 2053  USA  United States  2012       689  26.7   178.3    74.7        317.0
# 2054  USA  United States  2016       719  26.4   178.0    73.8        248.0
#
#       medals  predictions
# 2053     248        285.0
# 2054     264        235.0

# %%
test[test["team"] == "IND"]
# Out:
#     team country  year  athletes   age  height  weight  prev_medals  medals  \
# 907  IND   India  2012        95  26.0   174.2    72.7          3.0       6
# 908  IND   India  2016       130  26.1   170.0    66.3          6.0       2
#
#      predictions
# 907          7.0
# 908         12.0

# %% [markdown]
# ## **Check error by country**

# %%
errors = (test["medals"] - test["predictions"]).abs()

errors
# Out:
# 6       1.0
# 7       0.0
# 24      0.0
# 25      0.0
# 37      1.0
#        ...
# 2111    0.0
# 2131    0.0
# 2132    0.0
# 2142    1.0
# 2143    0.0
# Length: 405, dtype: float64

# %% [markdown]
# Group by team

# %%
error_by_team  = errors.groupby(test["team"]).mean()

error_by_team
# Out:
# team
# AFG    0.5
# ALB    0.0
# ALG    1.5
# AND    0.0
# ANG    0.0
#       ...
# VIE    1.5
# VIN    0.0
# YEM    0.0
# ZAM    0.0
# ZIM    0.5
# Length: 204, dtype: float64

# %% [markdown]
# Check how many medals each country earned on average

# %%
medals_by_team = test["medals"].groupby(test["team"]).mean()

# %% [markdown]
# Find the ratio between our errors

# %%
error_ratio = error_by_team / medals_by_team

error_ratio
# Out:
# team
# AFG    1.0
# ALB    NaN
# ALG    1.0
# AND    NaN
# ANG    NaN
#       ...
# VIE    1.5
# VIN    NaN
# YEM    NaN
# ZAM    NaN
# ZIM    inf
# Length: 204, dtype: float64

# %% [markdown]
# Take only values that are not missing from the error ratio remove NaN

# %%
error_ratio[~pd.isnull(error_ratio)]
# Out:
# team
# AFG    1.000000
# ALG    1.000000
# ARG    0.804878
# ARM    0.428571
# AUS    0.357143
#          ...
# USA    0.128906
# UZB    0.625000
# VEN    1.750000
# VIE    1.500000
# ZIM         inf
# Length: 103, dtype: float64

# %% [markdown]
# Clean up infinite values

# %%
import numpy as np
error_ratio = error_ratio[np.isfinite(error_ratio)]

# %%
error_ratio
# Out:
# team
# AFG    1.000000
# ALG    1.000000
# ARG    0.804878
# ARM    0.428571
# AUS    0.357143
#          ...
# UKR    0.951220
# USA    0.128906
# UZB    0.625000
# VEN    1.750000
# VIE    1.500000
# Length: 97, dtype: float64

# %% [markdown]
# Create a histogram for the error ratio

# %%
error_ratio.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# **Check which country tends to get a lot of medal from the olympics**

# %% [markdown]
# For example our error is very low for countries who tend to send more athletes to the olympics

# %%
error_ratio.sort_values()
# Out:
# team
# DOM    0.000000
# FRA    0.022472
# CAN    0.056452
# NZL    0.063492
# RUS    0.082353
#          ...
# MAR    2.000000
# EGY    2.400000
# HKG    3.000000
# POR    3.333333
# AUT    4.000000
# Length: 97, dtype: float64

# %% [markdown]
# ## **Save Our Model**

# %%
# import joblib 

# joblib.dump(reg, "Summer.Olympics_Medal_Prediction_V1.pkl")
# Out:
# ['Summer.Olympics_Medal_Prediction_V1.pkl']
